# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import timeit
import requests
from scipy.stats import linregress
from citipy import citipy
from datetime import datetime

# %%
#Create series or random lat and lngs
lats = np.random.uniform(-90.00, 90.00, size = 2000)
lngs = np.random.uniform(-180.00, 180.00, size = 2000)
lats_lngs = zip(lats, lngs)

# %%
#Add the coordinates to a list
coordinates = list(lats_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, add it to the cities list.
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 739

# %%
url = 'http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=662efc4a01e3710016a1712336407b0c'

# %%
# List of city data.
city_data = []

# Print to logger.
print('Beginning Data Retrieval')
print('-' * 25)

# Create a counter.
record_count = 1
set_count = 1
for index, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if(index % 50 == 0 and index >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city.
    city_url = f"{url}&q={city.replace(' ', '+')}"
    
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    record_count += 1
    
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the max temp, humidity, and cloudiness.
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_weather_description = city_weather['weather'][0]['description']
        try:
            city_rain_inches = city_weather['rain']['1h']
        except KeyError:
            city_rain_inches = 0
        try:
            city_snow_inches = city_weather['snow']['1h']
        except KeyError:
            city_snow_inches = 0
            
        # Append the city information into city_data.
        city_data.append(
        {
            'City': city,
            'Lat': city_lat,
            'Lng': city_lng,
            'Max Temp': city_max_temp,
            'Current Description': city_weather_description,
            'Rain (inches)': city_rain_inches,
            'Snow (inches)': city_snow_inches,
            'Humidity': city_humidity,
            'Cloudiness': city_clouds,
            'Wind Speed': city_wind,
            'Country': city_country
        })
    except:
        print('City not found. Skipping...')
        pass
# Indicate that the Data Loading is complete.
print('-' * 20)
print('Data Retrieval Complete')
print('-' * 20)
# Out:
# Beginning Data Retrieval
# -------------------------
# Processing Record 1 of Set 1 | saint george
# Processing Record 2 of Set 1 | jamestown
# Processing Record 3 of Set 1 | ushuaia
# Processing Record 4 of Set 1 | fairbanks
# Processing Record 5 of Set 1 | tecoanapa
# Processing Record 6 of Set 1 | belushya guba
# City not found. Skipping...
# Processing Record 7 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 8 of Set 1 | rikitea
# Processing Record 9 of Set 1 | aklavik
# Processing Record 10 of Set 1 | albany
# Processing Record 11 of Set 1 | new norfolk
# Processing Record 12 of Set 1 | qaanaaq
# Processing Record 13 of Set 1 | mataura
# Processing Record 14 of Set 1 | honiara
# Processing Record 15 of Set 1 | kruisfontein
# Processing Record 16 of Set 1 | ancud
# Processing Record 17 of Set 1 | thompson
# Processing Record 18 of Set 1 | east london
# Processing Record 19 of Set 1 | upernavik
# Processing Record 20 of Set 1 | touros
# Processing Record 21 of Set 1 | vaini
# Processing Record 22 of Set 1 | khatanga
# Processing Record 23 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 24 of Set 1 | bodaybo
# Processing Record 25 of Set 1 | chokurdakh
# Processing Record 26 of Set 1 | esperance
# Processing Record 27 of Set 1 | atuona
# Processing Record 28 of Set 1 | periyapatti
# Processing Record 29 of Set 1 | arraial do cabo
# Processing Record 30 of Set 1 | sao jose do belmonte
# Processing Record 31 of Set 1 | lagoa
# Processing Record 32 of Set 1 | olpe
# Processing Record 33 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 34 of Set 1 | hami
# Processing Record 35 of Set 1 | hilo
# Processing Record 36 of Set 1 | faanui
# Processing Record 37 of Set 1 | kodiak
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | busselton
# Processing Record 40 of Set 1 | hobyo
# Processing Record 41 of Set 1 | targu carbunesti
# Processing Record 42 of Set 1 | marmora
# Processing Record 43 of Set 1 | tasiilaq
# Processing Record 44 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 45 of Set 1 | kuche
# City not found. Skipping...
# Processing Record 46 of Set 1 | saleaula
# City not found. Skipping...
# Processing Record 47 of Set 1 | thinadhoo
# Processing Record 48 of Set 1 | hithadhoo
# Processing Record 49 of Set 1 | tuktoyaktuk
# Processing Record 50 of Set 1 | barrow
# Processing Record 1 of Set 2 | ust-omchug
# Processing Record 2 of Set 2 | srednekolymsk
# Processing Record 3 of Set 2 | vostok
# Processing Record 4 of Set 2 | finschhafen
# Processing Record 5 of Set 2 | port keats
# Processing Record 6 of Set 2 | przeworsk
# Processing Record 7 of Set 2 | kapaa
# Processing Record 8 of Set 2 | north bend
# Processing Record 9 of Set 2 | karamay
# City not found. Skipping...
# Processing Record 10 of Set 2 | mana
# Processing Record 11 of Set 2 | meulaboh
# Processing Record 12 of Set 2 | taitung
# Processing Record 13 of Set 2 | yellowknife
# Processing Record 14 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 15 of Set 2 | port alfred
# Processing Record 16 of Set 2 | wattegama
# Processing Record 17 of Set 2 | saint-philippe
# Processing Record 18 of Set 2 | dikson
# Processing Record 19 of Set 2 | nikolskoye
# Processing Record 20 of Set 2 | hasaki
# Processing Record 21 of Set 2 | hobart
# Processing Record 22 of Set 2 | sitka
# Processing Record 23 of Set 2 | goderich
# Processing Record 24 of Set 2 | havelock
# Processing Record 25 of Set 2 | mar del plata
# Processing Record 26 of Set 2 | ginda
# Processing Record 27 of Set 2 | cayenne
# Processing Record 28 of Set 2 | chagda
# City not found. Skipping...
# Processing Record 29 of Set 2 | mukhen
# Processing Record 30 of Set 2 | salalah
# Processing Record 31 of Set 2 | calama
# Processing Record 32 of Set 2 | kazaki
# Processing Record 33 of Set 2 | siguiri
# Processing Record 34 of Set 2 | punta arenas
# Processing Record 35 of Set 2 | cherskiy
# Processing Record 36 of Set 2 | harper
# Processing Record 37 of Set 2 | palu
# Processing Record 38 of Set 2 | cidreira
# Processing Record 39 of Set 2 | ilulissat
# Processing Record 40 of Set 2 | ialibu
# Processing Record 41 of Set 2 | provideniya
# Processing Record 42 of Set 2 | kudchi
# City not found. Skipping...
# Processing Record 43 of Set 2 | ribeira grande
# Processing Record 44 of Set 2 | whyalla
# Processing Record 45 of Set 2 | yar-sale
# Processing Record 46 of Set 2 | kavieng
# Processing Record 47 of Set 2 | mbigou
# Processing Record 48 of Set 2 | emba
# Processing Record 49 of Set 2 | takoradi
# Processing Record 50 of Set 2 | ahipara
# Processing Record 1 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 2 of Set 3 | pevek
# Processing Record 3 of Set 3 | bowen
# Processing Record 4 of Set 3 | durango
# Processing Record 5 of Set 3 | yulara
# Processing Record 6 of Set 3 | roding
# Processing Record 7 of Set 3 | taquaritinga
# Processing Record 8 of Set 3 | burnie
# Processing Record 9 of Set 3 | vestmannaeyjar
# Processing Record 10 of Set 3 | san policarpo
# Processing Record 11 of Set 3 | mayo
# Processing Record 12 of Set 3 | norman wells
# Processing Record 13 of Set 3 | hermanus
# Processing Record 14 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 15 of Set 3 | troitsko-pechorsk
# Processing Record 16 of Set 3 | brigham city
# Processing Record 17 of Set 3 | biltine
# Processing Record 18 of Set 3 | gat
# Processing Record 19 of Set 3 | torbay
# Processing Record 20 of Set 3 | bambous virieux
# Processing Record 21 of Set 3 | jalu
# Processing Record 22 of Set 3 | noyabrsk
# Processing Record 23 of Set 3 | sambava
# Processing Record 24 of Set 3 | rongcheng
# Processing Record 25 of Set 3 | nome
# Processing Record 26 of Set 3 | avarua
# Processing Record 27 of Set 3 | lae
# Processing Record 28 of Set 3 | dharmadam
# Processing Record 29 of Set 3 | nur
# Processing Record 30 of Set 3 | college
# Processing Record 31 of Set 3 | coihaique
# Processing Record 32 of Set 3 | alofi
# Processing Record 33 of Set 3 | maridi
# Processing Record 34 of Set 3 | makanya
# Processing Record 35 of Set 3 | bluff
# Processing Record 36 of Set 3 | tiksi
# Processing Record 37 of Set 3 | kieta
# Processing Record 38 of Set 3 | udachnyy
# Processing Record 39 of Set 3 | pizarro
# Processing Record 40 of Set 3 | bathsheba
# Processing Record 41 of Set 3 | lorengau
# Processing Record 42 of Set 3 | berlevag
# Processing Record 43 of Set 3 | kondinskoye
# Processing Record 44 of Set 3 | bredasdorp
# Processing Record 45 of Set 3 | dalaba
# Processing Record 46 of Set 3 | kabare
# Processing Record 47 of Set 3 | carutapera
# Processing Record 48 of Set 3 | maniitsoq
# Processing Record 49 of Set 3 | severo-kurilsk
# Processing Record 50 of Set 3 | butaritari
# Processing Record 1 of Set 4 | werda
# Processing Record 2 of Set 4 | huarmey
# Processing Record 3 of Set 4 | samalaeulu
# City not found. Skipping...
# Processing Record 4 of Set 4 | halalo
# City not found. Skipping...
# Processing Record 5 of Set 4 | morro bay
# Processing Record 6 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 7 of Set 4 | saskylakh
# Processing Record 8 of Set 4 | ostrovnoy
# Processing Record 9 of Set 4 | saint-pierre
# Processing Record 10 of Set 4 | bethel
# Processing Record 11 of Set 4 | chicama
# Processing Record 12 of Set 4 | dumaguil
# Processing Record 13 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 14 of Set 4 | boguchany
# Processing Record 15 of Set 4 | doctor arroyo
# Processing Record 16 of Set 4 | san quintin
# Processing Record 17 of Set 4 | meadow lake
# Processing Record 18 of Set 4 | saint-joseph
# Processing Record 19 of Set 4 | bolgar
# Processing Record 20 of Set 4 | te anau
# Processing Record 21 of Set 4 | adrar
# Processing Record 22 of Set 4 | westport
# Processing Record 23 of Set 4 | merauke
# Processing Record 24 of Set 4 | along
# Processing Record 25 of Set 4 | udimskiy
# Processing Record 26 of Set 4 | camargo
# Processing Record 27 of Set 4 | alyangula
# Processing Record 28 of Set 4 | rocha
# Processing Record 29 of Set 4 | camana
# Processing Record 30 of Set 4 | vao
# Processing Record 31 of Set 4 | crotone
# Processing Record 32 of Set 4 | lompoc
# Processing Record 33 of Set 4 | mykhaylivka
# Processing Record 34 of Set 4 | calvia
# Processing Record 35 of Set 4 | nishihara
# Processing Record 36 of Set 4 | port lincoln
# Processing Record 37 of Set 4 | vila franca do campo
# Processing Record 38 of Set 4 | guanica
# Processing Record 39 of Set 4 | zhigansk
# Processing Record 40 of Set 4 | kamenka
# Processing Record 41 of Set 4 | ascope
# Processing Record 42 of Set 4 | svetlaya
# Processing Record 43 of Set 4 | cape town
# Processing Record 44 of Set 4 | oktyabrskoye
# Processing Record 45 of Set 4 | laguna
# Processing Record 46 of Set 4 | ambulu
# Processing Record 47 of Set 4 | kedougou
# Processing Record 48 of Set 4 | burgersdorp
# Processing Record 49 of Set 4 | svetlyy
# Processing Record 50 of Set 4 | lolua
# City not found. Skipping...
# Processing Record 1 of Set 5 | tessalit
# Processing Record 2 of Set 5 | luderitz
# Processing Record 3 of Set 5 | castro
# Processing Record 4 of Set 5 | myski
# Processing Record 5 of Set 5 | kaitangata
# Processing Record 6 of Set 5 | tumannyy
# City not found. Skipping...
# Processing Record 7 of Set 5 | pelym
# Processing Record 8 of Set 5 | saint-paul
# Processing Record 9 of Set 5 | olafsvik
# Processing Record 10 of Set 5 | raga
# Processing Record 11 of Set 5 | tha maka
# Processing Record 12 of Set 5 | tiznit
# Processing Record 13 of Set 5 | pisco
# Processing Record 14 of Set 5 | saldanha
# Processing Record 15 of Set 5 | nizhnyaya omka
# Processing Record 16 of Set 5 | katsuura
# Processing Record 17 of Set 5 | geraldton
# Processing Record 18 of Set 5 | vilhena
# Processing Record 19 of Set 5 | waipawa
# Processing Record 20 of Set 5 | suntar
# Processing Record 21 of Set 5 | nara
# Processing Record 22 of Set 5 | palafrugell
# Processing Record 23 of Set 5 | chuy
# Processing Record 24 of Set 5 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 5 | saint anthony
# Processing Record 26 of Set 5 | nardaran
# Processing Record 27 of Set 5 | puerto ayora
# Processing Record 28 of Set 5 | mehamn
# Processing Record 29 of Set 5 | susuman
# Processing Record 30 of Set 5 | thaba nchu
# Processing Record 31 of Set 5 | san cristobal
# Processing Record 32 of Set 5 | codrington
# Processing Record 33 of Set 5 | mahudha
# Processing Record 34 of Set 5 | manaus
# Processing Record 35 of Set 5 | garden city
# Processing Record 36 of Set 5 | campina verde
# Processing Record 37 of Set 5 | samarai
# Processing Record 38 of Set 5 | lahat
# Processing Record 39 of Set 5 | tuatapere
# Processing Record 40 of Set 5 | ilebo
# Processing Record 41 of Set 5 | morant bay
# Processing Record 42 of Set 5 | birao
# Processing Record 43 of Set 5 | talcahuano
# Processing Record 44 of Set 5 | cumaribo
# City not found. Skipping...
# Processing Record 45 of Set 5 | boulder city
# Processing Record 46 of Set 5 | dali
# Processing Record 47 of Set 5 | vardo
# Processing Record 48 of Set 5 | galveston
# Processing Record 49 of Set 5 | martapura
# Processing Record 50 of Set 5 | namibe
# Processing Record 1 of Set 6 | hamilton
# Processing Record 2 of Set 6 | umzimvubu
# City not found. Skipping...
# Processing Record 3 of Set 6 | bengkulu
# Processing Record 4 of Set 6 | faro
# Processing Record 5 of Set 6 | bandarbeyla
# Processing Record 6 of Set 6 | tarhunah
# City not found. Skipping...
# Processing Record 7 of Set 6 | panguna
# Processing Record 8 of Set 6 | benguela
# Processing Record 9 of Set 6 | zatoka
# Processing Record 10 of Set 6 | lebu
# Processing Record 11 of Set 6 | hirara
# Processing Record 12 of Set 6 | dongsheng
# Processing Record 13 of Set 6 | mattru
# Processing Record 14 of Set 6 | leningradskiy
# Processing Record 15 of Set 6 | hebertville
# City not found. Skipping...
# Processing Record 16 of Set 6 | salym
# Processing Record 17 of Set 6 | avanigadda
# Processing Record 18 of Set 6 | chilca
# Processing Record 19 of Set 6 | abbeville
# Processing Record 20 of Set 6 | champerico
# Processing Record 21 of Set 6 | kungurtug
# Processing Record 22 of Set 6 | salinas
# Processing Record 23 of Set 6 | lasa
# Processing Record 24 of Set 6 | huambo
# Processing Record 25 of Set 6 | seoul
# Processing Record 26 of Set 6 | amderma
# City not found. Skipping...
# Processing Record 27 of Set 6 | carupano
# Processing Record 28 of Set 6 | richards bay
# Processing Record 29 of Set 6 | haines junction
# Processing Record 30 of Set 6 | jambi
# Processing Record 31 of Set 6 | wanning
# Processing Record 32 of Set 6 | eyl
# Processing Record 33 of Set 6 | shimoda
# Processing Record 34 of Set 6 | airai
# Processing Record 35 of Set 6 | georgetown
# Processing Record 36 of Set 6 | meyungs
# City not found. Skipping...
# Processing Record 37 of Set 6 | najran
# Processing Record 38 of Set 6 | taoudenni
# Processing Record 39 of Set 6 | port elizabeth
# Processing Record 40 of Set 6 | farmington
# Processing Record 41 of Set 6 | san carlos de bariloche
# Processing Record 42 of Set 6 | constitucion
# Processing Record 43 of Set 6 | souillac
# Processing Record 44 of Set 6 | ust-tsilma
# Processing Record 45 of Set 6 | shimanovsk
# Processing Record 46 of Set 6 | nanortalik
# Processing Record 47 of Set 6 | hohhot
# Processing Record 48 of Set 6 | portland
# Processing Record 49 of Set 6 | ibra
# Processing Record 50 of Set 6 | kashan
# Processing Record 1 of Set 7 | ashdod
# Processing Record 2 of Set 7 | viedma
# Processing Record 3 of Set 7 | carnarvon
# Processing Record 4 of Set 7 | singaraja
# Processing Record 5 of Set 7 | buqayq
# City not found. Skipping...
# Processing Record 6 of Set 7 | katangli
# Processing Record 7 of Set 7 | avera
# Processing Record 8 of Set 7 | kapit
# Processing Record 9 of Set 7 | turukhansk
# Processing Record 10 of Set 7 | saint-augustin
# Processing Record 11 of Set 7 | komsomolskiy
# Processing Record 12 of Set 7 | sur
# Processing Record 13 of Set 7 | porto novo
# Processing Record 14 of Set 7 | victoria
# Processing Record 15 of Set 7 | uhlove
# Processing Record 16 of Set 7 | pedernales
# Processing Record 17 of Set 7 | tupik
# Processing Record 18 of Set 7 | huilong
# Processing Record 19 of Set 7 | caravelas
# Processing Record 20 of Set 7 | burewala
# Processing Record 21 of Set 7 | gravdal
# Processing Record 22 of Set 7 | shenzhen
# Processing Record 23 of Set 7 | guerrero negro
# Processing Record 24 of Set 7 | kazalinsk
# City not found. Skipping...
# Processing Record 25 of Set 7 | ambon
# Processing Record 26 of Set 7 | balykshi
# Processing Record 27 of Set 7 | tazovskiy
# Processing Record 28 of Set 7 | wasilla
# Processing Record 29 of Set 7 | mocuba
# Processing Record 30 of Set 7 | taurage
# Processing Record 31 of Set 7 | teahupoo
# Processing Record 32 of Set 7 | clyde river
# Processing Record 33 of Set 7 | savannah bight
# Processing Record 34 of Set 7 | chivolo
# Processing Record 35 of Set 7 | concepcion del uruguay
# Processing Record 36 of Set 7 | muisne
# Processing Record 37 of Set 7 | whitianga
# Processing Record 38 of Set 7 | kambove
# Processing Record 39 of Set 7 | sao filipe
# Processing Record 40 of Set 7 | ahome
# Processing Record 41 of Set 7 | paamiut
# Processing Record 42 of Set 7 | tonj
# Processing Record 43 of Set 7 | barwadih
# Processing Record 44 of Set 7 | mahebourg
# Processing Record 45 of Set 7 | praia da vitoria
# Processing Record 46 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 47 of Set 7 | fenelon falls
# Processing Record 48 of Set 7 | kalamare
# Processing Record 49 of Set 7 | raudeberg
# Processing Record 50 of Set 7 | makakilo city
# Processing Record 1 of Set 8 | grindavik
# Processing Record 2 of Set 8 | bastia
# Processing Record 3 of Set 8 | jati
# Processing Record 4 of Set 8 | pirdop
# Processing Record 5 of Set 8 | geresk
# City not found. Skipping...
# Processing Record 6 of Set 8 | hofn
# Processing Record 7 of Set 8 | muros
# Processing Record 8 of Set 8 | sawtell
# Processing Record 9 of Set 8 | atka
# City not found. Skipping...
# Processing Record 10 of Set 8 | fort saint james
# Processing Record 11 of Set 8 | anadyr
# Processing Record 12 of Set 8 | auriflama
# Processing Record 13 of Set 8 | saint andrews
# Processing Record 14 of Set 8 | atbasar
# Processing Record 15 of Set 8 | dingle
# Processing Record 16 of Set 8 | tarakan
# Processing Record 17 of Set 8 | limbach-oberfrohna
# Processing Record 18 of Set 8 | wendo
# Processing Record 19 of Set 8 | thunder bay
# Processing Record 20 of Set 8 | puerto ayacucho
# Processing Record 21 of Set 8 | inongo
# Processing Record 22 of Set 8 | les cayes
# Processing Record 23 of Set 8 | yuzhno-yeniseyskiy
# City not found. Skipping...
# Processing Record 24 of Set 8 | eureka
# Processing Record 25 of Set 8 | pindiga
# Processing Record 26 of Set 8 | lazaro cardenas
# Processing Record 27 of Set 8 | mount darwin
# Processing Record 28 of Set 8 | capao bonito
# Processing Record 29 of Set 8 | kamsack
# Processing Record 30 of Set 8 | magdagachi
# Processing Record 31 of Set 8 | sao luis de montes belos
# Processing Record 32 of Set 8 | roma
# Processing Record 33 of Set 8 | pimentel
# Processing Record 34 of Set 8 | russell
# Processing Record 35 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 36 of Set 8 | natal
# Processing Record 37 of Set 8 | sao jose da coroa grande
# Processing Record 38 of Set 8 | doba
# Processing Record 39 of Set 8 | falealupo
# City not found. Skipping...
# Processing Record 40 of Set 8 | namatanai
# Processing Record 41 of Set 8 | brandfort
# Processing Record 42 of Set 8 | bonthe
# Processing Record 43 of Set 8 | tuim
# Processing Record 44 of Set 8 | le port
# Processing Record 45 of Set 8 | puerto madryn
# Processing Record 46 of Set 8 | sinnamary
# Processing Record 47 of Set 8 | dobryatino
# Processing Record 48 of Set 8 | fomboni
# Processing Record 49 of Set 8 | cooma
# Processing Record 50 of Set 8 | longlac
# City not found. Skipping...
# Processing Record 1 of Set 9 | kulhudhuffushi
# Processing Record 2 of Set 9 | fort-shevchenko
# Processing Record 3 of Set 9 | sechura
# Processing Record 4 of Set 9 | seda
# Processing Record 5 of Set 9 | sompeta
# Processing Record 6 of Set 9 | cabo san lucas
# Processing Record 7 of Set 9 | masyaf
# Processing Record 8 of Set 9 | minudasht
# Processing Record 9 of Set 9 | kwinana
# Processing Record 10 of Set 9 | lixourion
# Processing Record 11 of Set 9 | sharan
# Processing Record 12 of Set 9 | inderborskiy
# City not found. Skipping...
# Processing Record 13 of Set 9 | broken hill
# Processing Record 14 of Set 9 | tonantins
# Processing Record 15 of Set 9 | verkhnevilyuysk
# Processing Record 16 of Set 9 | red bluff
# Processing Record 17 of Set 9 | kilindoni
# Processing Record 18 of Set 9 | saint-francois
# Processing Record 19 of Set 9 | hun
# Processing Record 20 of Set 9 | pokrovsk
# Processing Record 21 of Set 9 | kahului
# Processing Record 22 of Set 9 | skiros
# City not found. Skipping...
# Processing Record 23 of Set 9 | mitu
# Processing Record 24 of Set 9 | port hawkesbury
# Processing Record 25 of Set 9 | fairhope
# Processing Record 26 of Set 9 | marquette
# Processing Record 27 of Set 9 | zaysan
# Processing Record 28 of Set 9 | kaseda
# Processing Record 29 of Set 9 | walvis bay
# Processing Record 30 of Set 9 | olden
# Processing Record 31 of Set 9 | causapscal
# Processing Record 32 of Set 9 | mozarlandia
# Processing Record 33 of Set 9 | porto murtinho
# Processing Record 34 of Set 9 | tabialan
# City not found. Skipping...
# Processing Record 35 of Set 9 | nosy varika
# Processing Record 36 of Set 9 | pochutla
# Processing Record 37 of Set 9 | mbandaka
# Processing Record 38 of Set 9 | ingleside
# Processing Record 39 of Set 9 | ketchikan
# Processing Record 40 of Set 9 | sobolevo
# Processing Record 41 of Set 9 | la seyne-sur-mer
# Processing Record 42 of Set 9 | kropotkin
# Processing Record 43 of Set 9 | pauini
# Processing Record 44 of Set 9 | padang
# Processing Record 45 of Set 9 | werota
# Processing Record 46 of Set 9 | la macarena
# Processing Record 47 of Set 9 | isangel
# Processing Record 48 of Set 9 | churapcha
# Processing Record 49 of Set 9 | palmer
# Processing Record 50 of Set 9 | limbang
# Processing Record 1 of Set 10 | lata
# Processing Record 2 of Set 10 | porto belo
# Processing Record 3 of Set 10 | ilabaya
# Processing Record 4 of Set 10 | mount gambier
# Processing Record 5 of Set 10 | millau
# Processing Record 6 of Set 10 | montes claros
# Processing Record 7 of Set 10 | winneba
# Processing Record 8 of Set 10 | kotelnich
# Processing Record 9 of Set 10 | mackay
# Processing Record 10 of Set 10 | talas
# Processing Record 11 of Set 10 | zyryanka
# Processing Record 12 of Set 10 | ayacucho
# Processing Record 13 of Set 10 | willowmore
# Processing Record 14 of Set 10 | svetlogorsk
# Processing Record 15 of Set 10 | sydney
# Processing Record 16 of Set 10 | gwadar
# Processing Record 17 of Set 10 | meghri
# Processing Record 18 of Set 10 | glazov
# Processing Record 19 of Set 10 | ponta do sol
# Processing Record 20 of Set 10 | pionerskiy
# Processing Record 21 of Set 10 | oga
# Processing Record 22 of Set 10 | henties bay
# Processing Record 23 of Set 10 | makarov
# Processing Record 24 of Set 10 | santa cruz de la palma
# Processing Record 25 of Set 10 | bukachacha
# Processing Record 26 of Set 10 | mogadishu
# Processing Record 27 of Set 10 | deputatskiy
# Processing Record 28 of Set 10 | phon
# Processing Record 29 of Set 10 | bilovec
# Processing Record 30 of Set 10 | bonfim
# Processing Record 31 of Set 10 | bubaque
# Processing Record 32 of Set 10 | sao joao da barra
# Processing Record 33 of Set 10 | nsanje
# Processing Record 34 of Set 10 | hanyang
# Processing Record 35 of Set 10 | rungata
# City not found. Skipping...
# Processing Record 36 of Set 10 | ankara
# Processing Record 37 of Set 10 | aasiaat
# Processing Record 38 of Set 10 | brigantine
# Processing Record 39 of Set 10 | iralaya
# Processing Record 40 of Set 10 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 10 | bauchi
# Processing Record 42 of Set 10 | corner brook
# Processing Record 43 of Set 10 | barranca de upia
# Processing Record 44 of Set 10 | kaeo
# Processing Record 45 of Set 10 | shirokiy
# Processing Record 46 of Set 10 | koboldo
# City not found. Skipping...
# Processing Record 47 of Set 10 | alta floresta
# Processing Record 48 of Set 10 | ocos
# Processing Record 49 of Set 10 | riyadh
# Processing Record 50 of Set 10 | klaksvik
# Processing Record 1 of Set 11 | kamaishi
# Processing Record 2 of Set 11 | basco
# Processing Record 3 of Set 11 | kenai
# Processing Record 4 of Set 11 | ulaangom
# Processing Record 5 of Set 11 | havre-saint-pierre
# Processing Record 6 of Set 11 | ziro
# Processing Record 7 of Set 11 | skjervoy
# Processing Record 8 of Set 11 | iqaluit
# Processing Record 9 of Set 11 | honningsvag
# Processing Record 10 of Set 11 | barra velha
# Processing Record 11 of Set 11 | san patricio
# Processing Record 12 of Set 11 | port moresby
# Processing Record 13 of Set 11 | hirtshals
# Processing Record 14 of Set 11 | coquimbo
# Processing Record 15 of Set 11 | grantham
# Processing Record 16 of Set 11 | roald
# Processing Record 17 of Set 11 | antsohihy
# Processing Record 18 of Set 11 | flin flon
# Processing Record 19 of Set 11 | hambantota
# Processing Record 20 of Set 11 | watsa
# Processing Record 21 of Set 11 | lichinga
# Processing Record 22 of Set 11 | colwyn bay
# Processing Record 23 of Set 11 | pacifica
# Processing Record 24 of Set 11 | tunxi
# City not found. Skipping...
# Processing Record 25 of Set 11 | chimbote
# Processing Record 26 of Set 11 | la ronge
# Processing Record 27 of Set 11 | aquiraz
# Processing Record 28 of Set 11 | zeya
# Processing Record 29 of Set 11 | mackenzie
# Processing Record 30 of Set 11 | chincha alta
# Processing Record 31 of Set 11 | marovoay
# Processing Record 32 of Set 11 | muncar
# Processing Record 33 of Set 11 | vila praia de ancora
# Processing Record 34 of Set 11 | sundumbili
# Processing Record 35 of Set 11 | felanitx
# Processing Record 36 of Set 11 | burica
# City not found. Skipping...
# Processing Record 37 of Set 11 | tyup
# Processing Record 38 of Set 11 | mount isa
# Processing Record 39 of Set 11 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 11 | ossora
# Processing Record 41 of Set 11 | kumi
# Processing Record 42 of Set 11 | lavrentiya
# Processing Record 43 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 44 of Set 11 | rawah
# Processing Record 45 of Set 11 | arys
# Processing Record 46 of Set 11 | asahikawa
# Processing Record 47 of Set 11 | englehart
# Processing Record 48 of Set 11 | maneadero
# Processing Record 49 of Set 11 | martaban
# Processing Record 50 of Set 11 | contai
# Processing Record 1 of Set 12 | camacha
# Processing Record 2 of Set 12 | borama
# City not found. Skipping...
# Processing Record 3 of Set 12 | chardara
# Processing Record 4 of Set 12 | hovd
# Processing Record 5 of Set 12 | muravlenko
# Processing Record 6 of Set 12 | prince rupert
# Processing Record 7 of Set 12 | vila velha
# Processing Record 8 of Set 12 | gorodishche
# Processing Record 9 of Set 12 | huaiyuan
# Processing Record 10 of Set 12 | okato
# Processing Record 11 of Set 12 | saint-ambroise
# Processing Record 12 of Set 12 | fukue
# Processing Record 13 of Set 12 | cairns
# Processing Record 14 of Set 12 | naifaru
# Processing Record 15 of Set 12 | gannan
# Processing Record 16 of Set 12 | nizhniy kuranakh
# Processing Record 17 of Set 12 | vilyuysk
# Processing Record 18 of Set 12 | huitzo
# Processing Record 19 of Set 12 | faya
# Processing Record 20 of Set 12 | shebalino
# Processing Record 21 of Set 12 | bar harbor
# Processing Record 22 of Set 12 | parker
# Processing Record 23 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 24 of Set 12 | brae
# Processing Record 25 of Set 12 | salinopolis
# Processing Record 26 of Set 12 | lazo
# Processing Record 27 of Set 12 | tocopilla
# Processing Record 28 of Set 12 | algeciras
# Processing Record 29 of Set 12 | halifax
# Processing Record 30 of Set 12 | beringovskiy
# Processing Record 31 of Set 12 | tarudant
# City not found. Skipping...
# Processing Record 32 of Set 12 | juneau
# Processing Record 33 of Set 12 | poum
# Processing Record 34 of Set 12 | baihar
# Processing Record 35 of Set 12 | port hardy
# Processing Record 36 of Set 12 | myre
# Processing Record 37 of Set 12 | diego de almagro
# Processing Record 38 of Set 12 | amudat
# Processing Record 39 of Set 12 | helena
# Processing Record 40 of Set 12 | omboue
# Processing Record 41 of Set 12 | urdzhar
# City not found. Skipping...
# Processing Record 42 of Set 12 | sabinas
# Processing Record 43 of Set 12 | kudahuvadhoo
# Processing Record 44 of Set 12 | batagay
# Processing Record 45 of Set 12 | nhulunbuy
# Processing Record 46 of Set 12 | bagotville
# Processing Record 47 of Set 12 | bani
# Processing Record 48 of Set 12 | batticaloa
# Processing Record 49 of Set 12 | gigmoto
# Processing Record 50 of Set 12 | chirongui
# Processing Record 1 of Set 13 | marsassoum
# Processing Record 2 of Set 13 | glubokoe
# City not found. Skipping...
# Processing Record 3 of Set 13 | taonan
# Processing Record 4 of Set 13 | demirci
# Processing Record 5 of Set 13 | arona
# Processing Record 6 of Set 13 | viligili
# City not found. Skipping...
# Processing Record 7 of Set 13 | san carlos
# Processing Record 8 of Set 13 | kauhajoki
# Processing Record 9 of Set 13 | dwarka
# Processing Record 10 of Set 13 | porto walter
# Processing Record 11 of Set 13 | andenes
# Processing Record 12 of Set 13 | darhan
# Processing Record 13 of Set 13 | neustrelitz
# Processing Record 14 of Set 13 | tamale
# Processing Record 15 of Set 13 | trelew
# Processing Record 16 of Set 13 | presidente epitacio
# Processing Record 17 of Set 13 | mariental
# Processing Record 18 of Set 13 | viseu
# Processing Record 19 of Set 13 | basoko
# Processing Record 20 of Set 13 | hualmay
# Processing Record 21 of Set 13 | matagami
# Processing Record 22 of Set 13 | solikamsk
# Processing Record 23 of Set 13 | novikovo
# Processing Record 24 of Set 13 | berberati
# Processing Record 25 of Set 13 | lago da pedra
# Processing Record 26 of Set 13 | cabadiangan
# Processing Record 27 of Set 13 | dunedin
# Processing Record 28 of Set 13 | nykoping
# Processing Record 29 of Set 13 | okha
# Processing Record 30 of Set 13 | nuuk
# Processing Record 31 of Set 13 | taltal
# Processing Record 32 of Set 13 | enshi
# Processing Record 33 of Set 13 | chhoti sadri
# Processing Record 34 of Set 13 | zabaykalsk
# Processing Record 35 of Set 13 | catamayo
# Processing Record 36 of Set 13 | quatre cocos
# Processing Record 37 of Set 13 | petatlan
# Processing Record 38 of Set 13 | kozhevnikovo
# Processing Record 39 of Set 13 | hay river
# Processing Record 40 of Set 13 | dolores
# Processing Record 41 of Set 13 | kontagora
# Processing Record 42 of Set 13 | acapulco
# Processing Record 43 of Set 13 | beidao
# Processing Record 44 of Set 13 | zhezkazgan
# Processing Record 45 of Set 13 | maumere
# Processing Record 46 of Set 13 | karasjok
# Processing Record 47 of Set 13 | fort saint john
# City not found. Skipping...
# Processing Record 48 of Set 13 | eenhana
# Processing Record 49 of Set 13 | biu
# Processing Record 50 of Set 13 | homer
# Processing Record 1 of Set 14 | adiake
# Processing Record 2 of Set 14 | moron
# Processing Record 3 of Set 14 | ijaki
# City not found. Skipping...
# Processing Record 4 of Set 14 | amatlan
# City not found. Skipping...
# Processing Record 5 of Set 14 | muscatine
# Processing Record 6 of Set 14 | talnakh
# Processing Record 7 of Set 14 | armentieres
# Processing Record 8 of Set 14 | tomatlan
# Processing Record 9 of Set 14 | kloulklubed
# Processing Record 10 of Set 14 | lakota
# Processing Record 11 of Set 14 | banda aceh
# Processing Record 12 of Set 14 | bani walid
# Processing Record 13 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 14 of Set 14 | lalibela
# Processing Record 15 of Set 14 | lumeje
# Processing Record 16 of Set 14 | santa cruz de tenerife
# Processing Record 17 of Set 14 | gazli
# Processing Record 18 of Set 14 | ullubiyaul
# Processing Record 19 of Set 14 | black forest
# Processing Record 20 of Set 14 | keti bandar
# Processing Record 21 of Set 14 | lianran
# Processing Record 22 of Set 14 | nyurba
# Processing Record 23 of Set 14 | linden
# Processing Record 24 of Set 14 | tulu bolo
# Processing Record 25 of Set 14 | chopda
# Processing Record 26 of Set 14 | monte aprazivel
# Processing Record 27 of Set 14 | whitehorse
# Processing Record 28 of Set 14 | almeirim
# Processing Record 29 of Set 14 | barnsley
# Processing Record 30 of Set 14 | cockburn town
# Processing Record 31 of Set 14 | karaul
# City not found. Skipping...
# Processing Record 32 of Set 14 | abonnema
# Processing Record 33 of Set 14 | darab
# Processing Record 34 of Set 14 | sanghar
# Processing Record 35 of Set 14 | la rioja
# Processing Record 36 of Set 14 | kirakira
# Processing Record 37 of Set 14 | vangaindrano
# Processing Record 38 of Set 14 | porto santo
# Processing Record 39 of Set 14 | saryagash
# Processing Record 40 of Set 14 | belem de sao francisco
# Processing Record 41 of Set 14 | houma
# Processing Record 42 of Set 14 | tahe
# Processing Record 43 of Set 14 | maraba
# Processing Record 44 of Set 14 | iskateley
# Processing Record 45 of Set 14 | ridgecrest
# Processing Record 46 of Set 14 | emerald
# Processing Record 47 of Set 14 | sibolga
# Processing Record 48 of Set 14 | sentyabrskiy
# City not found. Skipping...
# Processing Record 49 of Set 14 | lishui
# Processing Record 50 of Set 14 | czluchow
# Processing Record 1 of Set 15 | okhotsk
# Processing Record 2 of Set 15 | esteli
# Processing Record 3 of Set 15 | kavaratti
# Processing Record 4 of Set 15 | jeremie
# Processing Record 5 of Set 15 | japura
# Processing Record 6 of Set 15 | kaka
# Processing Record 7 of Set 15 | sorland
# Processing Record 8 of Set 15 | karkaralinsk
# City not found. Skipping...
# Processing Record 9 of Set 15 | ust-maya
# Processing Record 10 of Set 15 | nampula
# Processing Record 11 of Set 15 | sabla
# Processing Record 12 of Set 15 | joniskis
# Processing Record 13 of Set 15 | mayumba
# Processing Record 14 of Set 15 | batagay-alyta
# Processing Record 15 of Set 15 | severnoye
# Processing Record 16 of Set 15 | bonavista
# Processing Record 17 of Set 15 | kotlas
# Processing Record 18 of Set 15 | conakry
# Processing Record 19 of Set 15 | atambua
# Processing Record 20 of Set 15 | pueblo
# Processing Record 21 of Set 15 | tevaitoa
# Processing Record 22 of Set 15 | los llanos de aridane
# Processing Record 23 of Set 15 | scottsburgh
# City not found. Skipping...
# Processing Record 24 of Set 15 | mandera
# Processing Record 25 of Set 15 | kupino
# Processing Record 26 of Set 15 | smithers
# Processing Record 27 of Set 15 | shenjiamen
# Processing Record 28 of Set 15 | beisfjord
# Processing Record 29 of Set 15 | plyussa
# Processing Record 30 of Set 15 | rundu
# Processing Record 31 of Set 15 | kuusankoski
# Processing Record 32 of Set 15 | oussouye
# Processing Record 33 of Set 15 | yangambi
# Processing Record 34 of Set 15 | teya
# Processing Record 35 of Set 15 | buraydah
# Processing Record 36 of Set 15 | akyab
# Processing Record 37 of Set 15 | kayankulam
# Processing Record 38 of Set 15 | mildura
# Processing Record 39 of Set 15 | pangnirtung
# --------------------
# Data Retrieval Complete
# --------------------

# %%
len(city_data)
# Out:
# 681

# %%
#Convert the array of dictionaries to a Pandas DF
city_data_df = pd.DataFrame(city_data)
city_data_df.head
# Out:
# <bound method NDFrame.head of              City      Lat       Lng  Max Temp Current Description  \
# 0    saint george  37.1041 -113.5841     86.63           clear sky
# 1       jamestown  42.0970  -79.2353     63.72       broken clouds
# 2         ushuaia -54.8000  -68.3000     38.86           clear sky
# 3       fairbanks  64.8378 -147.7164     35.60       broken clouds
# 4       tecoanapa  16.5167  -98.7500     79.95     overcast clouds
# ..            ...      ...       ...       ...                 ...
# 676      buraydah  26.3260   43.9750     70.25    scattered clouds
# 677         akyab  20.1500   92.9000     79.57          light rain
# 678    kayankulam   9.1833   76.5000     78.13     overcast clouds
# 679       mildura -34.2000  142.1500     73.08     overcast clouds
# 680   pangnirtung  66.1451  -65.7125     31.93          few clouds
#
#      Rain (inches)  Snow (inches)  Humidity  Cloudiness  Wind Speed Country
# 0             0.00            0.0        26           1        3.00      US
# 1             0.00            0.0        84          75        1.99      US
# 2             0.00            0.0        70           0        1.14      AR
# 3             0.00            0.0        76          75        4.61      US
# 4             0.00            0.0        83         100        4.45      MX
# ..             ...            ...       ...         ...         ...     ...
# 676           0.00            0.0        34          38        4.41      SA
# 677           0.56            0.0        88         100        3.80      MM
# 678           0.00            0.0        87         100        9.91      IN
# 679           0.00            0.0        28          88        9.22      AU
# 680           0.00            0.0        78          19        1.36      CA
#
# [681 rows x 11 columns]>

# %%
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0  saint george      US  37.1041 -113.5841     86.63        26           1
# 1     jamestown      US  42.0970  -79.2353     63.72        84          75
# 2       ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 3     fairbanks      US  64.8378 -147.7164     35.60        76          75
# 4     tecoanapa      MX  16.5167  -98.7500     79.95        83         100
# 5       rikitea      PF -23.1203 -134.9692     73.65        72          33
# 6       aklavik      CA  68.2191 -135.0107     32.83        93          96
# 7        albany      US  42.6001  -73.9662     55.58        86           4
# 8   new norfolk      AU -42.7826  147.0587     58.91        35          50
# 9       qaanaaq      GL  77.4840  -69.3632     19.44        60          79
#
#    Wind Speed Current Description
# 0        3.00           clear sky
# 1        1.99       broken clouds
# 2        1.14           clear sky
# 3        4.61       broken clouds
# 4        4.45     overcast clouds
# 5       19.60    scattered clouds
# 6        4.34     overcast clouds
# 7        5.12           clear sky
# 8        4.25    scattered clouds
# 9        8.34       broken clouds

# %%
#export to csv
city_data_df.to_csv('/Volumes/Pud SSD/Analytics/Columbia University Bootcamp/Module6/World_Weather_Analysis/Weather_database.csv')
city_data_df
# Out:
#              City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    saint george      US  37.1041 -113.5841     86.63        26           1
# 1       jamestown      US  42.0970  -79.2353     63.72        84          75
# 2         ushuaia      AR -54.8000  -68.3000     38.86        70           0
# 3       fairbanks      US  64.8378 -147.7164     35.60        76          75
# 4       tecoanapa      MX  16.5167  -98.7500     79.95        83         100
# ..            ...     ...      ...       ...       ...       ...         ...
# 676      buraydah      SA  26.3260   43.9750     70.25        34          38
# 677         akyab      MM  20.1500   92.9000     79.57        88         100
# 678    kayankulam      IN   9.1833   76.5000     78.13        87         100
# 679       mildura      AU -34.2000  142.1500     73.08        28          88
# 680   pangnirtung      CA  66.1451  -65.7125     31.93        78          19
#
#      Wind Speed Current Description
# 0          3.00           clear sky
# 1          1.99       broken clouds
# 2          1.14           clear sky
# 3          4.61       broken clouds
# 4          4.45     overcast clouds
# ..          ...                 ...
# 676        4.41    scattered clouds
# 677        3.80          light rain
# 678        9.91     overcast clouds
# 679        9.22     overcast clouds
# 680        1.36          few clouds
#
# [681 rows x 9 columns]
