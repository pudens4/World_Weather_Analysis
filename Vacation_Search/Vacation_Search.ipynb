# %% [markdown]
# ## Deliverable 2. Create a Customer Travel Destinations Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
#from config import g_key

# Configure gmaps API key
gmaps.configure(api_key='AIzaSyCYQLO0fXGmxlrWLISuhHbnQMknOFRGfn8')

# %%
# 1. Import the WeatherPy_database.csv file. 
city_data_df = pd.read_csv("/Volumes/Pud SSD/Analytics/Columbia University Bootcamp/Module6/World_Weather_Analysis/Weather_Database/Weather_database.csv")
# city_data_df.head()
# Out:
#    Unnamed: 0          City Country      Lat       Lng  Max Temp  Humidity  \
# 0           0  saint george      US  37.1041 -113.5841     86.63        26
# 1           1     jamestown      US  42.0970  -79.2353     63.72        84
# 2           2       ushuaia      AR -54.8000  -68.3000     38.86        70
# 3           3     fairbanks      US  64.8378 -147.7164     35.60        76
# 4           4     tecoanapa      MX  16.5167  -98.7500     79.95        83
#
#    Cloudiness  Wind Speed Current Description
# 0           1        3.00           clear sky
# 1          75        1.99       broken clouds
# 2           0        1.14           clear sky
# 3          75        4.61       broken clouds
# 4         100        4.45     overcast clouds

# %%
# 2. Prompt the user to enter minimum and maximum temperature criteria 
min_temp = float(input(('put min temp ')))
max_temp = float(input(('put max temp ')))
# Out:
# put min temp50
# put max temp70

# %%
# 3. Filter the city_data_df DataFrame using the input statements to create a new DataFrame using the loc method.
new_city_df = city_data_df.loc[(city_data_df['Max Temp']<= max_temp ) & (city_data_df['Max Temp']>= min_temp)]
new_city_df.head()
# Out:
#     Unnamed: 0          City Country      Lat       Lng  Max Temp  Humidity  \
# 1            1     jamestown      US  42.0970  -79.2353     63.72        84
# 7            7        albany      US  42.6001  -73.9662     55.58        86
# 8            8   new norfolk      AU -42.7826  147.0587     58.91        35
# 10          10       mataura      NZ -46.1927  168.8643     53.47        34
# 12          12  kruisfontein      ZA -34.0033   24.7314     55.49        94
#
#     Cloudiness  Wind Speed Current Description
# 1           75        1.99       broken clouds
# 7            4        5.12           clear sky
# 8           50        4.25    scattered clouds
# 10           4        2.06           clear sky
# 12           7        4.05           clear sky

# %%
# 4a. Determine if there are any empty rows.
new_city_df.count()
# Out:
# Unnamed: 0             278
# City                   278
# Country                273
# Lat                    278
# Lng                    278
# Max Temp               278
# Humidity               278
# Cloudiness             278
# Wind Speed             278
# Current Description    278
# dtype: int64

# %%
# 4b. Drop any empty rows and create a new DataFrame that doesn’t have empty rows.
clean_data_city = new_city_df.dropna()
clean_data_city.count()
# Out:
# Unnamed: 0             273
# City                   273
# Country                273
# Lat                    273
# Lng                    273
# Max Temp               273
# Humidity               273
# Cloudiness             273
# Wind Speed             273
# Current Description    273
# dtype: int64

# %%
# 5a. Create DataFrame called hotel_df to store hotel names along with city, country, max temp, and coordinates.
hotel_df = clean_data_city[["City", "Country", "Max Temp", "Current Description", "Lat", "Lng"]].copy()

# 5b. Create a new column "Hotel Name"
hotel_df["Hotel Name"] = ""
hotel_df.head(10)
# Out:
#             City Country  Max Temp Current Description      Lat       Lng  \
# 1      jamestown      US     63.72       broken clouds  42.0970  -79.2353
# 7         albany      US     55.58           clear sky  42.6001  -73.9662
# 8    new norfolk      AU     58.91    scattered clouds -42.7826  147.0587
# 10       mataura      NZ     53.47           clear sky -46.1927  168.8643
# 12  kruisfontein      ZA     55.49           clear sky -34.0033   24.7314
# 15   east london      ZA     66.56     overcast clouds -33.0153   27.9116
# 22     esperance      AU     60.64          light rain -33.8667  121.9000
# 27         lagoa      PT     66.56       broken clouds  39.0500  -27.9833
# 28          olpe      DE     59.61     overcast clouds  51.0333    7.8500
# 34     busselton      AU     63.09       broken clouds -33.6500  115.3333
#
#    Hotel Name
# 1
# 7
# 8
# 10
# 12
# 15
# 22
# 27
# 28
# 34

# %%
# 6a. Set parameters to search for hotels with 5000 meters.
params = {
    "radius": 50000,
    "type": "lodging",
    "key": 'AIzaSyCYQLO0fXGmxlrWLISuhHbnQMknOFRGfn8'
}

# 6b. Iterate through the hotel DataFrame.
for i, row in hotel_df.iterrows():
    # 6c. Get latitude and longitude from DataFrame
    lat = row["Lat"]
    lng = row["Lng"]
    
    # 6d. Set up the base URL for the Google Directions API to get JSON data.
    url = "https://maps.googleapis.com/maps/api/place/nearbysearch/json"

    # 6e. Make request and retrieve the JSON data from the search. 
    hotels = requests.get(url, params=params).json()
    print("-------")
    
    # 6f. Get the first hotel from the results and store the name, if a hotel isn't found skip the city.
    
    try:
        hotel_df.loc[index, "Hotel Name"] = hotels["results"][0]["name"]
        
    except (IndexError):
        print("Hotel not found... skipping.")
# Out:
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.
# -------
# Hotel not found... skipping.

# %%
# 7. Drop the rows where there is no Hotel Name.
clean_hotel_df = hotel_df.dropna()

# %%
# 8a. Create the output File (CSV)
output_data_file = "Vacation_database.csv"
# 8b. Export the City_Data into a csv
clean_hotel_df.to_csv(output_data_file, index_label="City_ID")
clean_hotel_df
# Out:
#              City Country  Max Temp Current Description      Lat       Lng  \
# 1       jamestown      US     63.72       broken clouds  42.0970  -79.2353
# 7          albany      US     55.58           clear sky  42.6001  -73.9662
# 8     new norfolk      AU     58.91    scattered clouds -42.7826  147.0587
# 10        mataura      NZ     53.47           clear sky -46.1927  168.8643
# 12   kruisfontein      ZA     55.49           clear sky -34.0033   24.7314
# ..            ...     ...       ...                 ...      ...       ...
# 652       nampula      MZ     69.75          few clouds -15.1165   39.2666
# 658     bonavista      CA     54.12     overcast clouds  48.6499  -53.1147
# 667      smithers      CA     53.92          light rain  54.7804 -127.1743
# 669     beisfjord      NO     55.04     overcast clouds  68.3751   17.5988
# 674      yangambi      CD     66.38       broken clouds   0.8102   24.4336
#
#     Hotel Name
# 1
# 7
# 8
# 10
# 12
# ..         ...
# 652
# 658
# 667
# 669
# 674
#
# [273 rows x 7 columns]

# %%
# 9. Using the template add city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """

"""

# 10a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in clean_hotel_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = clean_hotel_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map. 
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)
# 11b. Display the figure
fig
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-ce65faa12cc0> in <module>
#       1 # 11a. Add a marker layer for each city to the map.
# ----> 2 heat_layer = gmaps.heatmap_layer(locations, weights=max_temp, dissipating=False, max_intensity=300, point_radius=4)
#       3 marker_layer = gmaps.marker_layer(locations)
#       4 fig.add_layer(heat_layer)
#       5 fig.add_layer(marker_layer)
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/gmaps/heatmap.py in heatmap_layer(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     262         A :class:`gmaps.Heatmap` or a :class:`gmaps.WeightedHeatmap` widget.
#     263     """
# --> 264     widget_args, is_weighted = _heatmap_options(
#     265         locations, weights, max_intensity, dissipating, point_radius,
#     266         opacity, gradient
#
# ~/opt/anaconda3/envs/PythonData/lib/python3.8/site-packages/gmaps/heatmap.py in _heatmap_options(locations, weights, max_intensity, dissipating, point_radius, opacity, gradient)
#     205         widget_args = {'locations': locations}
#     206     else:
# --> 207         if len(weights) != len(locations):
#     208             raise ValueError(
#     209                 'weights must be of the same length as locations or None')
#
# TypeError: object of type 'float' has no len()
